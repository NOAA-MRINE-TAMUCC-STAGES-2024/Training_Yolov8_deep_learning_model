# %%
import os

import os
import torch
from ultralytics import YOLO
# Enable CUDA and disable CUDA debugging options
# Remove the following lines if they were set before
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # Uncomment this to disable CUDA (do not use if you want to enable CUDA)
# os.environ['CUDA_LAUNCH_BLOCKING'] = '1'   # Optional: for better error reporting


# Check if CUDA is enabled
print("CUDA Available:", torch.cuda.is_available())  # Should print True if CUDA is available

# Load the pretrained YOLOv8 model checkpoint
model = YOLO(r'yolov8n.yaml')

# Train the model using your custom dataset
model.train(
    data=r"C:\MS_2024\Marine Stages\Airial images from NOAA\Yolo training satalight quality\yolo training satalight quality\data.yaml",  # Path to data.yaml
    epochs=600,     # Number of training epochs
    imgsz=100,      # Image size (adjust as needed; 640 is standard)
    batch=8,        # Batch size (adjust based on your GPU memory)
    device=0        # Use GPU device 0; change to 'cpu' if no GPU is available
)
# Out:
# CUDA Available: True
# New https://pypi.org/project/ultralytics/8.3.48 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.98  Python-3.8.19 torch-2.4.1 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from ultralytics import YOLO
import os

import os
import torch
from ultralytics import YOLO
# Load YOLO model
model = YOLO('yolov8n.yaml')

# Validate dataset setup
model.val(data="C:/MS_2024/Marine Stages/Airial images from NOAA/Yolo training satalight quality/yolo training satalight quality/data.yaml")
# Out:
# Ultralytics YOLOv8.2.98  Python-3.8.19 torch-2.4.1 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 31,920 gradients, 8.7 GFLOPs
# val: Scanning C:\MS_2024\Marine Stages\Airial images from NOAA\Yolo training satalight quality\yolo training satalight
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<0
#                    all          6          6          0          0          0          0
# Speed: 4.6ms preprocess, 32.9ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs\detect\val2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\envs\env_pytorch\lib\site-packages\IPython\core\formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
# ...

# %%
import os
import torch
from ultralytics import YOLO

# Check if CUDA is enabled
print("CUDA Available:", torch.cuda.is_available())  # Should print True if CUDA is available

# Load the pretrained YOLOv8 model checkpoint
model = YOLO(r"C:\MS_2024\Marine Stages\Airial images from NOAA\Yolo training satalight quality\yolo training satalight quality\yolov8m_best.pt")

# Train the model using your custom dataset
model.train(
    data=r"C:\MS_2024\Marine Stages\Airial images from NOAA\Yolo training satalight quality\yolo training satalight quality\data.yaml",  # Path to data.yaml
    epochs=200,     # Number of training epochs
    imgsz=100,      # Image size (adjust as needed; 640 is standard)
    batch=8,        # Batch size (adjust based on your GPU memory)
    device=0        # Use GPU device 0; change to 'cpu' if no GPU is available
)
# Out:
# CUDA Available: True
# New https://pypi.org/project/ultralytics/8.3.37 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.98  Python-3.8.19 torch-2.4.1 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
import os
import torch
from ultralytics import YOLO

# Check if CUDA is enabled
print("CUDA Available:", torch.cuda.is_available())  # Should print True if CUDA is available

# Load the pretrained YOLOv8 model checkpoint
model = YOLO(r"C:\MS_2024\Marine Stages\Airial images from NOAA\Yolo training satalight quality\yolo training satalight quality\yolov8m_best.pt")

# Train the model using your custom dataset
model.train(
    data=r"C:\MS_2024\Marine Stages\Airial images from NOAA\Yolo training satalight quality\yolo training satalight quality\data.yaml",  # Path to data.yaml
    epochs=200,     # Number of training epochs
    imgsz=100,      # Image size (adjust as needed; 640 is standard)
    batch=8,        # Batch size (adjust based on your GPU memory)
    device=0        # Use GPU device 0; change to 'cpu' if no GPU is available
)
# Out:
# CUDA Available: True
# New https://pypi.org/project/ultralytics/8.3.48 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.98  Python-3.8.19 torch-2.4.1 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...
